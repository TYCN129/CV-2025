# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, ConcatDataset
from torchvision import datasets, transforms
import torchvision
import matplotlib.pyplot as plt
import os

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transformations for the dataset
transform = transforms.Compose([
    transforms.ToTensor()
])

# Load the MNIST dataset
mnist_path = './data'
train_dataset = datasets.MNIST(root=mnist_path, train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root=mnist_path, train=False, download=True, transform=transform)
full_dataset = ConcatDataset([train_dataset, test_dataset])

# Define the VAE model
class VAE(nn.Module):
    def __init__(self, latent_dim=2):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, kernel_size=7)
        )
        self.fc1 = nn.Conv2d(64, latent_dim, kernel_size=1)
        self.fc2 = nn.Conv2d(64, latent_dim, kernel_size=1)
        self.fc3 = nn.ConvTranspose2d(latent_dim, 64, kernel_size=1)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=7),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def encode(self, x):
        x = self.encoder(x)
        mu = self.fc1(x).squeeze()
        logvar = self.fc2(x).squeeze()
        return mu, logvar

    def decode(self, z):
        z = z.unsqueeze(-1).unsqueeze(-1)
        x = self.fc3(z)
        x = self.decoder(x)
        return x

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# Loss Function
def loss_function(recon_x, x, mu, logvar):
    BCE = nn.functional.binary_cross_entropy(recon_x, x, reduction='sum')
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + KLD

# Training Function
def train_vae(model, dataset, config):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=config['lr'])
    data_loader = DataLoader(dataset, batch_size=config['batch_size'], shuffle=True)
    
    for epoch in range(config['num_epochs']):
        model.train()
        train_loss = 0
        for batch_idx, (data, _) in enumerate(data_loader):
            data = data.to(device)
            optimizer.zero_grad()
            recon_batch, mu, logvar = model(data)
            loss = loss_function(recon_batch, data, mu, logvar)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()
        print(f'Epoch {epoch + 1}, Loss: {train_loss / len(data_loader.dataset):.4f}')
    
    # Save model
    os.makedirs(os.path.dirname(config['save_path']), exist_ok=True)
    torch.save(model.state_dict(), config['save_path'])

# Sampling Function
def sample_from_vae(model, latent_dim, num_samples=64):
    model.eval()
    with torch.no_grad():
        z = torch.randn(num_samples, latent_dim).to(device)
        samples = model.decode(z).cpu()
        grid = torchvision.utils.make_grid(samples, nrow=8, pad_value=1)
        plt.figure(figsize=(8, 8))
        plt.title("Generated Samples from Latent Space")
        plt.imshow(grid.permute(1, 2, 0).squeeze(), cmap='gray')
        plt.axis('off')
        plt.show()

# Config
config = {
    'lr': 5e-4,
    'num_epochs': 5,
    'batch_size': 32,
    'save_path': 'models/vae_mnist.pth'
}

# Run Training
model = VAE(latent_dim=16)
train_vae(model, full_dataset, config)

# Load model & Sample
model.load_state_dict(torch.load(config['save_path'], map_location=device))
model.to(device)
sample_from_vae(model, latent_dim=16)
# Out:
# Epoch 1, Loss: 167.7034
# Epoch 2, Loss: 116.8328
# Epoch 3, Loss: 110.4176
# Epoch 4, Loss: 107.9120
# Epoch 5, Loss: 106.6457

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

# ----------------------------------------
#   VAE2: Residual Super-Resolution VAE
# ----------------------------------------
class VAE2(nn.Module):
    def __init__(self, latent_dim=16, patch_size=7):
        super().__init__()
        self.latent_dim = latent_dim
        self.patch_size = patch_size
        self.num_patches = (28 // patch_size) ** 2

        # Encoder: residual map → latent parameters μ₂, logσ₂²
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),  # → 16×28×28
            nn.ReLU(),
            nn.MaxPool2d(2),                              # → 16×14×14
            nn.Conv2d(16, 32, kernel_size=3, padding=1),  # → 32×14×14
            nn.ReLU(),
            nn.MaxPool2d(2),                              # → 32× 7×7
            nn.Conv2d(32, 64, kernel_size=7)              # → 64× 1×1
        )
        self.fc_mu     = nn.Linear(64, latent_dim)
        self.fc_logvar = nn.Linear(64, latent_dim)

        # Positional embedding for patch index
        self.pos_emb = nn.Embedding(self.num_patches, latent_dim)

        # Decoder: ( z₂ + pos_emb + flattened patch) → 7×7 residual patch
        in_dim = latent_dim * 2 + patch_size * patch_size
        self.decoder_fc = nn.Sequential(
            nn.Linear(in_dim, 128),
            nn.ReLU(),
            nn.Linear(128, patch_size * patch_size),
            nn.Tanh()  # residual in [-1,1]
        )


    def encode(self, residual):
        h = self.encoder(residual)        # [B,64,1,1]
        h = h.view(h.size(0), -1)         # [B,64]
        mu     = self.fc_mu(h)            # [B,latent_dim]
        logvar = self.fc_logvar(h)        # [B,latent_dim]
        return mu, logvar

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std             # [B,latent_dim]

    def decode_patch(self, z2, patch, idx):
        pf = patch.contiguous().view(patch.size(0), -1)  # [B,49]
        pe = self.pos_emb(idx).unsqueeze(0).expand(z2.size(0), -1)  # [B,latent_dim]
        inp = torch.cat([z2, pe*0.1, pf], dim=1)  # [B,2*latent_dim+49]
        out = self.decoder_fc(inp)                # [B,49]
        return out.view(-1, 1, self.patch_size, self.patch_size)

    # def decode_patch(self, z1, z2, patch, idx):
    #     pf = patch.contiguous().view(patch.size(0), -1)  # [B,49]
    #     pe = self.pos_emb(idx).unsqueeze(0).expand(z1.size(0), -1)  # [B,latent_dim]
    #     # print('decode debug')
    #     # print('Printing z1 and z2 and pe and pf') # TO CHECK
    #     # print(z1.shape, z2.shape, pe.shape, pf.shape)
    #     # print(z1[z1>1].shape, z2[z2>1].shape, pe[pe>1].shape, pf[pf>1].shape)
    #     # print(z1.mean(), z2.mean(), pe.mean(), pf.mean())

    #     # Normalizing z1, z2, pe, pf
    #     # z1n = self.norm_z(z1)
    #     # z2n = self.norm_z(z2)
    #     # pen = self.norm_z(pe)
    #     # pfn = self.norm_pf(pf)
    #     # inp = torch.cat([z1n, z2n, pen, pfn], dim=1)

    #     inp = torch.cat([z1, z2, pe, pf], dim=1)  # checking for 0
    #     # inp = torch.cat([z1, z2, pe, pf], dim=1)  # [B,3*latent_dim+49]
    #     out = self.decoder_fc(inp)                # [B,49]
    #     return out.view(-1, 1, self.patch_size, self.patch_size)

    def extract_patches(self, img):
        patches = []
        idx = 0
        for i in range(0, 28, self.patch_size):
            for j in range(0, 28, self.patch_size):
                patches.append((img[:, :, i:i+self.patch_size, j:j+self.patch_size], idx))
                idx += 1
        return patches

    def stitch_patches(self, patches, shape):
        B, C, H, W = shape
        full = torch.zeros((B, C, H, W), device=patches[0][0].device)
        for patch, idx in patches:
            i, j = divmod(idx, H // self.patch_size)
            full[:, :, i*self.patch_size:(i+1)*self.patch_size,
                      j*self.patch_size:(j+1)*self.patch_size] += patch
        return full

    def forward(self, original, vae1_out):
        residual_gt = original - vae1_out
        mu2, logvar2 = self.encode(residual_gt)
        z2 = self.reparameterize(mu2, logvar2)

        patches = self.extract_patches(vae1_out)
        res_patches = []
        for patch, idx in patches:
            rp = self.decode_patch(z2, patch, torch.tensor(idx, device=z2.device))
            res_patches.append((rp, idx))

        pred_residual = self.stitch_patches(res_patches, original.shape)
        return pred_residual, mu2, logvar2


# ----------------------------------------
#        VAE2 Loss & Training Loop
# ----------------------------------------
def kl_div(mu, logvar):
    return -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

def vae2_loss(orig, vae1_out, pred_residual, mu2, logvar2):
    target_residual = (orig - vae1_out)
    rec = F.mse_loss(pred_residual, target_residual, reduction='sum')

    if (target_residual.abs() > 0.2).any():
        mask = 1.0
    else:
        mask = 0.01     # less weightage to balance empty patches

    # print('mu2 vs logvar2', mu2[mu2>0.1].shape, logvar2[logvar2>0.1].shape)
    # print('rec vs kl', rec, kl_div(mu2, logvar2))
    return mask*(rec + kl_div(mu2, logvar2))

# Train VAE2 using existing DataLoader from VAE1
def train_vae2(vae1, vae2, loader, config, device):
    vae2.to(device)
    vae1.to(device).eval()
    opt = optim.Adam(vae2.parameters(), lr=config['lr'])

    import matplotlib.pyplot as plt

    for epoch in range(config['num_epochs']):
        tot = 0.0
        for batch_idx, (imgs, _) in enumerate(loader):
            imgs = imgs.to(device)

            mu1, log1 = vae1.encode(imgs)
            z1        = vae1.reparameterize(mu1, log1)
            O1        = vae1.decode(z1)


            residual, mu2, log2 = vae2(imgs, O1)

            # Debugging
            gt = imgs - O1
            print('imgs', imgs[imgs>0.1].shape)
            print('gt', gt[gt>0.1].shape)
            print('residual', residual[residual>0.1].shape)

            loss = vae2_loss(imgs, O1, residual, mu2, log2)

            opt.zero_grad()
            loss.backward()
            opt.step()
            tot += loss.item()

        if epoch % 2== 0:
            print('Images from epoch', epoch)
            print('shapes im', imgs.cpu().shape)
            print('shapes O1', O1.detach().cpu().shape)
            for i in range(min(2, imgs.size(0))):
                fig, axs = plt.subplots(1, 4, figsize=(12, 3))
                axs[0].imshow(imgs[i, 0].cpu(), cmap='gray', vmin=0, vmax=1)
                axs[0].set_title("Original")
                axs[0].axis('off')

                axs[1].imshow(O1[i, 0].detach().cpu(), cmap='gray', vmin=0, vmax=1)
                axs[1].set_title("VAE1 Output")
                axs[1].axis('off')

                axs[2].imshow((imgs[i, 0] - O1[i, 0].detach()).cpu(), cmap='gray', vmin=-1, vmax=1)
                axs[2].set_title("Actual Residual")
                axs[2].axis('off')

                axs[3].imshow(residual[i, 0].detach().cpu(), cmap='gray', vmin=-1, vmax=1)
                axs[3].set_title("VAE2 Residual")
                axs[3].axis('off')

                plt.tight_layout()
                plt.show()

        print(f"Epoch {epoch+1}/{config['num_epochs']}  Loss: {tot/len(loader.dataset):.4f}")

    os.makedirs(os.path.dirname(config['save_path']), exist_ok=True)
    torch.save(vae2.state_dict(), config['save_path'])

# %%
# ----------------------------------------
#   Generate and Compare Samples (VAE1 vs VAE1+VAE2)
# ----------------------------------------
def sample_and_compare(vae1, vae2, config, device, num_samples=8):
    """
    Samples from VAE1 and VAE2 pipeline and plots side-by-side on same [0,1] scale:
     - VAE1-only sample
     - Combined VAE1+VAE2 sample
    """
    vae1.eval()
    vae2.eval()
    import matplotlib.pyplot as plt
    with torch.no_grad():
        # 1) Sample z1 and generate base samples
        z1 = torch.randn(num_samples, config['latent_dim'], device=device)
        O1 = vae1.decode(z1)  # [num_samples,1,28,28]

        # 2) Generate residuals and combined output
        residual, _, _ = vae2(O1, O1, z1)
        O2 = torch.clamp(O1 + residual, 0, 1)    # with residual scaling

        # 3) Plot side-by-side with consistent scaling
        for i in range(num_samples):
            fig, axs = plt.subplots(1, 2, figsize=(6, 3))
            axs[0].imshow(O1[i,0].cpu(), cmap='gray', vmin=0, vmax=1)
            axs[0].set_title('VAE1 Sample')
            axs[0].axis('off')

            axs[1].imshow(O2[i,0].cpu(), cmap='gray', vmin=0, vmax=1)
            axs[1].set_title('VAE1+VAE2 Sample')
            axs[1].axis('off')

            plt.tight_layout()
            plt.show()

# %%
# ----------------------------------------
#  Example: reuse existing train_loader
# ----------------------------------------
if __name__ == "__main__":
    config = {
        'lr': 1e-4,
        'batch_size': 32,
        'num_epochs': 10,
        'latent_dim': 16,
        'patch_size': 7,
        'save_path': 'models/vae2_mnist.pth'
    }
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Assume train_loader comes from VAE1 setup and dataset already downloaded
    # e.g. from previous script:
    # transform = transforms.ToTensor()
    # train_ds = datasets.MNIST('./data', train=True, download=False, transform=transform)
    train_loader = DataLoader(full_dataset, batch_size=config['batch_size'], shuffle=True)

    vae1 = VAE(latent_dim=config['latent_dim']).to(device)
    vae1.load_state_dict(torch.load('models/vae_mnist.pth', map_location=device))
    vae1.eval()

    vae2 = VAE2(latent_dim=config['latent_dim'], patch_size=config['patch_size']).to(device)

    train_vae2(vae1, vae2, train_loader, config, device)
# Out:
# imgs torch.Size([4023])
# gt torch.Size([1637])
# residual torch.Size([5219])
# imgs torch.Size([4489])
# gt torch.Size([1757])
# residual torch.Size([5178])
# imgs torch.Size([4227])
# gt torch.Size([1632])
# residual torch.Size([5408])
# imgs torch.Size([4182])
# gt torch.Size([1726])
# residual torch.Size([4683])
# imgs torch.Size([4570])
# gt torch.Size([1833])
# residual torch.Size([5021])
# imgs torch.Size([4065])
# gt torch.Size([1687])
# residual torch.Size([5193])
# imgs torch.Size([4178])
# gt torch.Size([1626])
# residual torch.Size([4647])
# imgs torch.Size([4277])
# gt torch.Size([1615])
# residual torch.Size([4801])
# imgs torch.Size([4680])
# gt torch.Size([1909])
# residual torch.Size([4566])
# imgs torch.Size([4270])
# gt torch.Size([1797])
# residual torch.Size([4697])
# imgs torch.Size([4360])
# gt torch.Size([1688])
# residual torch.Size([4567])
# imgs torch.Size([4177])
# gt torch.Size([1691])
# residual torch.Size([4352])
# imgs torch.Size([4316])
# gt torch.Size([1582])
# residual torch.Size([4389])
# imgs torch.Size([4548])
# gt torch.Size([1802])
# residual torch.Size([4421])
# imgs torch.Size([4536])
# gt torch.Size([1835])
# residual torch.Size([4377])
# imgs torch.Size([4324])
# gt torch.Size([1723])
# residual torch.Size([4354])
# imgs torch.Size([4350])
# gt torch.Size([1678])
# residual torch.Size([3989])
# imgs torch.Size([4492])
# gt torch.Size([1816])
# residual torch.Size([4145])
# imgs torch.Size([4674])
# gt torch.Size([1859])
# residual torch.Size([4176])
# imgs torch.Size([3965])
# gt torch.Size([1728])
# residual torch.Size([3451])
# imgs torch.Size([4034])
# gt torch.Size([1663])
# residual torch.Size([3608])
# imgs torch.Size([4265])
# gt torch.Size([1793])
# residual torch.Size([3798])
# imgs torch.Size([4147])
# gt torch.Size([1755])
# residual torch.Size([3852])
# imgs torch.Size([4098])
# gt torch.Size([1714])
# residual torch.Size([3524])
# imgs torch.Size([4167])
# gt torch.Size([1701])
# residual torch.Size([3309])
# imgs torch.Size([4207])
# gt torch.Size([1732])
# residual torch.Size([3411])
# imgs torch.Size([4154])
# gt torch.Size([1613])
# residual torch.Size([3290])
# imgs torch.Size([4413])
# gt torch.Size([1763])
# residual torch.Size([3469])
# imgs torch.Size([4508])
# gt torch.Size([1761])
# residual torch.Size([3429])
# imgs torch.Size([4316])
# gt torch.Size([1584])
# residual torch.Size([3566])
# imgs torch.Size([4287])
# gt torch.Size([1798])
# residual torch.Size([3155])
# imgs torch.Size([4604])
# gt torch.Size([1774])
# residual torch.Size([3568])
# imgs torch.Size([4314])
# gt torch.Size([1608])
# residual torch.Size([3122])
# imgs torch.Size([4696])
# gt torch.Size([1759])
# residual torch.Size([3043])
# imgs torch.Size([4132])
# gt torch.Size([1730])
# residual torch.Size([2885])
# imgs torch.Size([4601])
# gt torch.Size([1905])
# residual torch.Size([3036])
# imgs torch.Size([4670])
# gt torch.Size([1731])
# residual torch.Size([3078])
# imgs torch.Size([4236])
# gt torch.Size([1563])
# residual torch.Size([2745])
# imgs torch.Size([4186])
# gt torch.Size([1780])
# residual torch.Size([2666])
# imgs torch.Size([4346])
# gt torch.Size([1758])
# residual torch.Size([2669])
# imgs torch.Size([4181])
# gt torch.Size([1774])
# residual torch.Size([2733])
# imgs torch.Size([4381])
# gt torch.Size([1733])
# residual torch.Size([2483])
# imgs torch.Size([4431])
# gt torch.Size([1660])
# residual torch.Size([2650])
# imgs torch.Size([4080])
# gt torch.Size([1463])
# residual torch.Size([2813])
# imgs torch.Size([4473])
# gt torch.Size([1922])
# residual torch.Size([2481])
# imgs torch.Size([4078])
# gt torch.Size([1727])
# residual torch.Size([2591])
# imgs torch.Size([4188])
# gt torch.Size([1586])
# residual torch.Size([2549])
# imgs torch.Size([4514])
# gt torch.Size([1909])
# residual torch.Size([2655])
# imgs torch.Size([4174])
# gt torch.Size([1789])
# residual torch.Size([2149])
# imgs torch.Size([4307])
# gt torch.Size([1646])
# residual torch.Size([2298])
# imgs torch.Size([4462])
# gt torch.Size([1834])
# residual torch.Size([2466])
# imgs torch.Size([4239])
# gt torch.Size([1768])
# residual torch.Size([2422])
# imgs torch.Size([4585])
# gt torch.Size([1701])
# residual torch.Size([2307])
# imgs torch.Size([4435])
# gt torch.Size([1635])
# residual torch.Size([2348])
# imgs torch.Size([4565])
# gt torch.Size([1776])
# residual torch.Size([2200])
# imgs torch.Size([4167])
# gt torch.Size([1611])
# residual torch.Size([2333])
# imgs torch.Size([4810])
# gt torch.Size([1938])
# residual torch.Size([2374])
# imgs torch.Size([3731])
# gt torch.Size([1384])
# residual torch.Size([2222])
# imgs torch.Size([4304])
# gt torch.Size([1695])
# residual torch.Size([2152])
# imgs torch.Size([4452])
# gt torch.Size([1795])
# residual torch.Size([2101])
# imgs torch.Size([4496])
# gt torch.Size([1644])
# residual torch.Size([2137])
# imgs torch.Size([4298])
# gt torch.Size([1551])
# residual torch.Size([2164])
# imgs torch.Size([4495])
# gt torch.Size([1690])
# residual torch.Size([2013])
# imgs torch.Size([4509])
# gt torch.Size([1885])
# residual torch.Size([1869])
# imgs torch.Size([4766])
# gt torch.Size([1867])
# residual torch.Size([2152])
# imgs torch.Size([4282])
# gt torch.Size([1712])
# residual torch.Size([1844])
# imgs torch.Size([4340])
# gt torch.Size([1692])
# residual torch.Size([2070])
# imgs torch.Size([4257])
# gt torch.Size([1691])
# residual torch.Size([2067])
# imgs torch.Size([4337])
# gt torch.Size([1682])
# residual torch.Size([2028])
# imgs torch.Size([4510])
# gt torch.Size([1704])
# residual torch.Size([1898])
# imgs torch.Size([4520])
# gt torch.Size([1798])
# residual torch.Size([2010])
# imgs torch.Size([3919])
# gt torch.Size([1554])
# residual torch.Size([1999])
# imgs torch.Size([4482])
# gt torch.Size([1667])
# residual torch.Size([1731])
# imgs torch.Size([4465])
# gt torch.Size([1677])
# residual torch.Size([1946])
# imgs torch.Size([4421])
# gt torch.Size([1780])
# residual torch.Size([1609])
# imgs torch.Size([4028])
# gt torch.Size([1620])
# residual torch.Size([1626])
# imgs torch.Size([4556])
# gt torch.Size([1635])
# residual torch.Size([2145])
# imgs torch.Size([4488])
# gt torch.Size([1747])
# residual torch.Size([1711])
# imgs torch.Size([4666])
# gt torch.Size([1723])
# residual torch.Size([1864])
# imgs torch.Size([4178])
# gt torch.Size([1635])
# residual torch.Size([1730])
# imgs torch.Size([4097])
# gt torch.Size([1642])
# residual torch.Size([1920])
# imgs torch.Size([4616])
# gt torch.Size([1960])
# residual torch.Size([1874])
# imgs torch.Size([4691])
# gt torch.Size([1848])
# residual torch.Size([1716])
# imgs torch.Size([4190])
# gt torch.Size([1727])
# residual torch.Size([1858])
# imgs torch.Size([4297])
# gt torch.Size([1867])
# residual torch.Size([1761])
# imgs torch.Size([3865])
# gt torch.Size([1645])
# residual torch.Size([1478])
# imgs torch.Size([4520])
# gt torch.Size([1705])
# residual torch.Size([1470])
# imgs torch.Size([4065])
# gt torch.Size([1778])
# residual torch.Size([1559])
# imgs torch.Size([4502])
# gt torch.Size([1738])
# residual torch.Size([1514])
# imgs torch.Size([4321])
# gt torch.Size([1648])
# residual torch.Size([1621])
# imgs torch.Size([4603])
# gt torch.Size([1856])
# residual torch.Size([1446])
# imgs torch.Size([4482])
# gt torch.Size([1975])
# residual torch.Size([1548])
# imgs torch.Size([4185])
# gt torch.Size([1705])
# residual torch.Size([1443])
# imgs torch.Size([4292])
# gt torch.Size([1612])
# residual torch.Size([1441])
# imgs torch.Size([4305])
# gt torch.Size([1703])
# residual torch.Size([1610])
# imgs torch.Size([4379])
# gt torch.Size([1670])
# residual torch.Size([1722])
# imgs torch.Size([4606])
# gt torch.Size([1776])
# residual torch.Size([1635])
# imgs torch.Size([4211])
# gt torch.Size([1599])
# residual torch.Size([1410])
# imgs torch.Size([4739])
# gt torch.Size([1793])
# residual torch.Size([1329])
# imgs torch.Size([4308])
# gt torch.Size([1733])
# residual torch.Size([1577])
# imgs torch.Size([4248])
# gt torch.Size([1700])
# residual torch.Size([1469])
# imgs torch.Size([4363])
# gt torch.Size([1729])
# residual torch.Size([1602])
# imgs torch.Size([4737])
# gt torch.Size([1875])
# residual torch.Size([1538])
# imgs torch.Size([4528])
# gt torch.Size([1717])
# residual torch.Size([1470])
# imgs torch.Size([4351])
# gt torch.Size([1830])
# residual torch.Size([1813])
# imgs torch.Size([4515])
# gt torch.Size([1744])
# residual torch.Size([1388])
# imgs torch.Size([4838])
# gt torch.Size([1656])
# residual torch.Size([1107])
# imgs torch.Size([4608])
# gt torch.Size([1837])
# residual torch.Size([1453])
# imgs torch.Size([4409])
# gt torch.Size([1672])
# residual torch.Size([1377])
# imgs torch.Size([4491])
# gt torch.Size([1845])
# residual torch.Size([1636])
# imgs torch.Size([4437])
# gt torch.Size([1842])
# residual torch.Size([1318])
# imgs torch.Size([4330])
# gt torch.Size([1691])
# residual torch.Size([1582])
# imgs torch.Size([4411])
# gt torch.Size([1636])
# residual torch.Size([1338])
# imgs torch.Size([4433])
# gt torch.Size([1766])
# residual torch.Size([1707])
# imgs torch.Size([4250])
# gt torch.Size([1623])
# residual torch.Size([1499])
# imgs torch.Size([4606])
# gt torch.Size([1770])
# residual torch.Size([1353])
# imgs torch.Size([4342])
# gt torch.Size([1646])
# residual torch.Size([1531])
# imgs torch.Size([4641])
# gt torch.Size([1809])
# residual torch.Size([1404])
# imgs torch.Size([4221])
# gt torch.Size([1621])
# residual torch.Size([1184])
# imgs torch.Size([4490])
# gt torch.Size([1702])
# residual torch.Size([1249])
# imgs torch.Size([4797])
# gt torch.Size([1780])
# residual torch.Size([1273])
# imgs torch.Size([4554])
# gt torch.Size([1845])
# residual torch.Size([1416])
# imgs torch.Size([4031])
# gt torch.Size([1607])
# residual torch.Size([1083])
# imgs torch.Size([4067])
# gt torch.Size([1727])
# residual torch.Size([1416])
# imgs torch.Size([4463])
# gt torch.Size([1800])
# residual torch.Size([1160])
# imgs torch.Size([4101])
# gt torch.Size([1819])
# residual torch.Size([1220])
# imgs torch.Size([4281])
# gt torch.Size([1702])
# residual torch.Size([1415])
# imgs torch.Size([4523])
# gt torch.Size([1784])
# residual torch.Size([1352])
# imgs torch.Size([4239])
# gt torch.Size([1698])
# residual torch.Size([1268])
# imgs torch.Size([4300])
# gt torch.Size([1794])
# residual torch.Size([1155])
# imgs torch.Size([4665])
# gt torch.Size([1703])
# residual torch.Size([1215])
# imgs torch.Size([4388])
# gt torch.Size([1764])
# residual torch.Size([1203])
# imgs torch.Size([4605])
# gt torch.Size([1830])
# residual torch.Size([1083])
# imgs torch.Size([4178])
# gt torch.Size([1705])
# residual torch.Size([1038])
# imgs torch.Size([3876])
# gt torch.Size([1527])
# residual torch.Size([1086])
# imgs torch.Size([4595])
# gt torch.Size([1750])
# residual torch.Size([1348])
# imgs torch.Size([4477])
# gt torch.Size([1915])
# residual torch.Size([1177])
# imgs torch.Size([4197])
# gt torch.Size([1631])
# residual torch.Size([1160])
# imgs torch.Size([4460])
# gt torch.Size([1791])
# residual torch.Size([1103])
# imgs torch.Size([4483])
# gt torch.Size([1751])
# residual torch.Size([1190])
# imgs torch.Size([4607])
# gt torch.Size([1781])
# residual torch.Size([1089])
# imgs torch.Size([5198])
# gt torch.Size([2056])
# residual torch.Size([1193])
# imgs torch.Size([4441])
# gt torch.Size([1790])
# residual torch.Size([998])
# imgs torch.Size([4062])
# gt torch.Size([1536])
# residual torch.Size([992])
# imgs torch.Size([4191])
# gt torch.Size([1702])
# residual torch.Size([1252])
# imgs torch.Size([4314])
# gt torch.Size([1661])
# residual torch.Size([882])
# imgs torch.Size([4460])
# gt torch.Size([1816])
# residual torch.Size([1090])
# imgs torch.Size([4362])
# gt torch.Size([1707])
# residual torch.Size([914])
# imgs torch.Size([3914])
# gt torch.Size([1715])
# residual torch.Size([1282])
# imgs torch.Size([4479])
# gt torch.Size([1628])
# residual torch.Size([959])
# imgs torch.Size([4043])
# gt torch.Size([1622])
# residual torch.Size([1182])
# imgs torch.Size([4513])
# gt torch.Size([1773])
# residual torch.Size([882])
# imgs torch.Size([4669])
# gt torch.Size([1933])
# residual torch.Size([1005])
# imgs torch.Size([4619])
# gt torch.Size([1701])
# residual torch.Size([922])
# imgs torch.Size([4514])
# gt torch.Size([1725])
# residual torch.Size([987])
# imgs torch.Size([4203])
# gt torch.Size([1566])
# residual torch.Size([1057])
# imgs torch.Size([4530])
# gt torch.Size([1829])
# residual torch.Size([904])
# imgs torch.Size([4036])
# gt torch.Size([1412])
# residual torch.Size([1029])
# imgs torch.Size([4405])
# gt torch.Size([1656])
# residual torch.Size([1039])
# imgs torch.Size([4142])
# gt torch.Size([1723])
# residual torch.Size([919])
# imgs torch.Size([4711])
# gt torch.Size([1930])
# residual torch.Size([1194])
# imgs torch.Size([4477])
# gt torch.Size([1687])
# residual torch.Size([871])
# imgs torch.Size([4024])
# gt torch.Size([1677])
# residual torch.Size([860])
# imgs torch.Size([4364])
# gt torch.Size([1698])
# residual torch.Size([691])
# imgs torch.Size([4297])
# gt torch.Size([1602])
# residual torch.Size([965])
# imgs torch.Size([4163])
# gt torch.Size([1552])
# residual torch.Size([833])
# imgs torch.Size([4312])
# gt torch.Size([1756])
# residual torch.Size([723])
# imgs torch.Size([4203])
# gt torch.Size([1891])
# residual torch.Size([1020])
# imgs torch.Size([4378])
# gt torch.Size([1711])
# residual torch.Size([859])
# imgs torch.Size([4399])
# gt torch.Size([1586])
# residual torch.Size([903])
# imgs torch.Size([4513])
# gt torch.Size([1881])
# residual torch.Size([923])
# imgs torch.Size([4431])
# gt torch.Size([1530])
# residual torch.Size([1050])
# imgs torch.Size([4663])
# gt torch.Size([1978])
# residual torch.Size([1090])
# imgs torch.Size([4587])
# gt torch.Size([1677])
# residual torch.Size([916])
# imgs torch.Size([4720])
# gt torch.Size([1869])
# residual torch.Size([944])
# imgs torch.Size([4561])
# gt torch.Size([1869])
# residual torch.Size([923])
# imgs torch.Size([4150])
# gt torch.Size([1520])
# residual torch.Size([882])
# imgs torch.Size([4443])
# gt torch.Size([1821])
# residual torch.Size([794])
# imgs torch.Size([4414])
# gt torch.Size([1813])
# residual torch.Size([791])
# imgs torch.Size([4382])
# gt torch.Size([1618])
# residual torch.Size([820])
# imgs torch.Size([4305])
# gt torch.Size([1632])
# residual torch.Size([949])
# imgs torch.Size([4231])
# gt torch.Size([1732])
# residual torch.Size([1063])
# imgs torch.Size([4551])
# gt torch.Size([1877])
# residual torch.Size([842])
# imgs torch.Size([4014])
# gt torch.Size([1664])
# residual torch.Size([879])
# imgs torch.Size([4255])
# gt torch.Size([1696])
# residual torch.Size([937])
# imgs torch.Size([4650])
# gt torch.Size([1651])
# residual torch.Size([930])
# imgs torch.Size([4194])
# gt torch.Size([1655])
# residual torch.Size([717])
# imgs torch.Size([4944])
# gt torch.Size([1981])
# residual torch.Size([613])
# imgs torch.Size([4220])
# gt torch.Size([1600])
# residual torch.Size([736])
# imgs torch.Size([4410])
# gt torch.Size([1769])
# residual torch.Size([818])
# imgs torch.Size([4240])
# gt torch.Size([1683])
# residual torch.Size([635])
# imgs torch.Size([4351])
# gt torch.Size([1612])
# residual torch.Size([841])
# imgs torch.Size([3934])
# gt torch.Size([1654])
# residual torch.Size([791])
# imgs torch.Size([4837])
# gt torch.Size([1991])
# residual torch.Size([686])
# imgs torch.Size([4556])
# gt torch.Size([1939])
# residual torch.Size([704])
# imgs torch.Size([4196])
# gt torch.Size([1784])
# residual torch.Size([693])
# imgs torch.Size([4123])
# gt torch.Size([1596])
# residual torch.Size([665])
# imgs torch.Size([4514])
# gt torch.Size([1855])
# residual torch.Size([644])
# imgs torch.Size([4050])
# gt torch.Size([1522])
# residual torch.Size([807])
# imgs torch.Size([4637])
# gt torch.Size([1809])
# residual torch.Size([674])
# imgs torch.Size([4380])
# gt torch.Size([1730])
# residual torch.Size([815])
# imgs torch.Size([3781])
# gt torch.Size([1539])
# residual torch.Size([551])
# imgs torch.Size([4389])
# gt torch.Size([1605])
# residual torch.Size([730])
# imgs torch.Size([4660])
# gt torch.Size([1635])
# residual torch.Size([664])
# imgs torch.Size([5052])
# gt torch.Size([2031])
# residual torch.Size([816])
# imgs torch.Size([4228])
# gt torch.Size([1612])
# residual torch.Size([676])
# imgs torch.Size([4120])
# gt torch.Size([1570])
# residual torch.Size([677])
# imgs torch.Size([4372])
# gt torch.Size([1764])
# residual torch.Size([617])
# imgs torch.Size([4438])
# gt torch.Size([1722])
# residual torch.Size([645])
# imgs torch.Size([4358])
# gt torch.Size([1742])
# residual torch.Size([639])
# imgs torch.Size([4082])
# gt torch.Size([1536])
# residual torch.Size([673])
# imgs torch.Size([4015])
# gt torch.Size([1454])
# residual torch.Size([716])
# imgs torch.Size([3947])
# gt torch.Size([1615])
# residual torch.Size([741])
# imgs torch.Size([4557])
# gt torch.Size([1859])
# residual torch.Size([484])
# imgs torch.Size([4202])
# gt torch.Size([1486])
# residual torch.Size([475])
# imgs torch.Size([4309])
# gt torch.Size([1708])
# residual torch.Size([723])
# imgs torch.Size([4155])
# gt torch.Size([1437])
# residual torch.Size([840])
# imgs torch.Size([4137])
# gt torch.Size([1598])
# residual torch.Size([505])
# imgs torch.Size([4477])
# gt torch.Size([1822])
# residual torch.Size([678])
# imgs torch.Size([4360])
# gt torch.Size([1687])
# residual torch.Size([751])
# imgs torch.Size([4409])
# gt torch.Size([1787])
# residual torch.Size([751])
# imgs torch.Size([4238])
# gt torch.Size([1573])
# residual torch.Size([490])
# imgs torch.Size([4423])
# gt torch.Size([1787])
# residual torch.Size([594])
# imgs torch.Size([4281])
# gt torch.Size([1802])
# residual torch.Size([639])
# imgs torch.Size([4630])
# gt torch.Size([1763])
# residual torch.Size([722])
# imgs torch.Size([4200])
# gt torch.Size([1603])
# residual torch.Size([478])
# imgs torch.Size([4649])
# gt torch.Size([1605])
# residual torch.Size([668])
# imgs torch.Size([4233])
# gt torch.Size([1536])
# residual torch.Size([742])
# imgs torch.Size([4597])
# gt torch.Size([1776])
# residual torch.Size([529])
# imgs torch.Size([4525])
# gt torch.Size([1770])
# residual torch.Size([533])
# imgs torch.Size([4689])
# gt torch.Size([1857])
# residual torch.Size([679])
# imgs torch.Size([4448])
# gt torch.Size([1889])
# residual torch.Size([514])
# imgs torch.Size([4291])
# gt torch.Size([1597])
# residual torch.Size([734])
# imgs torch.Size([4353])
# gt torch.Size([1751])
# residual torch.Size([696])
# imgs torch.Size([4154])
# gt torch.Size([1750])
# residual torch.Size([528])
# imgs torch.Size([4689])
# gt torch.Size([1661])
# residual torch.Size([562])
# imgs torch.Size([4334])
# gt torch.Size([1789])
# residual torch.Size([457])
# imgs torch.Size([4307])
# gt torch.Size([1559])
# residual torch.Size([670])
# imgs torch.Size([4558])
# gt torch.Size([1737])
# residual torch.Size([585])
# imgs torch.Size([4052])
# gt torch.Size([1576])
# residual torch.Size([592])
# imgs torch.Size([4329])
# gt torch.Size([1596])
# residual torch.Size([491])
# imgs torch.Size([4769])
# gt torch.Size([1939])
# residual torch.Size([478])
# imgs torch.Size([4348])
# gt torch.Size([1869])
# residual torch.Size([577])
# imgs torch.Size([4442])
# gt torch.Size([1676])
# residual torch.Size([609])
# imgs torch.Size([4182])
# gt torch.Size([1682])
# residual torch.Size([551])
# imgs torch.Size([4458])
# gt torch.Size([1780])
# residual torch.Size([520])
# imgs torch.Size([4422])
# gt torch.Size([1638])
# residual torch.Size([477])
# imgs torch.Size([4414])
# gt torch.Size([1740])
# residual torch.Size([482])
# imgs torch.Size([4390])
# gt torch.Size([1746])
# residual torch.Size([428])
# imgs torch.Size([4333])
# gt torch.Size([1551])
# residual torch.Size([640])
# imgs torch.Size([4305])
# gt torch.Size([1893])
# residual torch.Size([360])
# imgs torch.Size([4526])
# gt torch.Size([1747])
# residual torch.Size([639])
# imgs torch.Size([4135])
# gt torch.Size([1607])
# residual torch.Size([477])
# imgs torch.Size([4546])
# gt torch.Size([1777])
# residual torch.Size([424])
# imgs torch.Size([4254])
# gt torch.Size([1787])
# residual torch.Size([540])
# imgs torch.Size([3667])
# gt torch.Size([1542])
# residual torch.Size([471])
# imgs torch.Size([4350])
# gt torch.Size([1781])
# residual torch.Size([572])
# imgs torch.Size([4237])
# gt torch.Size([1592])
# residual torch.Size([527])
# imgs torch.Size([4571])
# gt torch.Size([1653])
# residual torch.Size([454])
# imgs torch.Size([4993])
# gt torch.Size([1907])
# residual torch.Size([531])
# imgs torch.Size([4452])
# gt torch.Size([1779])
# residual torch.Size([513])
# imgs torch.Size([4719])
# gt torch.Size([1675])
# residual torch.Size([485])
# imgs torch.Size([4442])
# gt torch.Size([1886])
# residual torch.Size([373])
# imgs torch.Size([4176])
# gt torch.Size([1432])
# residual torch.Size([363])
# imgs torch.Size([4400])
# gt torch.Size([1706])
# residual torch.Size([506])
# imgs torch.Size([4198])
# gt torch.Size([1707])
# residual torch.Size([472])
# imgs torch.Size([4303])
# gt torch.Size([1617])
# residual torch.Size([530])
# imgs torch.Size([4307])
# gt torch.Size([1686])
# residual torch.Size([541])
# imgs torch.Size([4323])
# gt torch.Size([1606])
# residual torch.Size([455])
# imgs torch.Size([4388])
# gt torch.Size([1856])
# residual torch.Size([605])
# imgs torch.Size([4462])
# gt torch.Size([1823])
# residual torch.Size([646])
# imgs torch.Size([4254])
# gt torch.Size([1631])
# residual torch.Size([488])
# imgs torch.Size([4339])
# gt torch.Size([1685])
# residual torch.Size([423])
# imgs torch.Size([4363])
# gt torch.Size([1624])
# residual torch.Size([362])
# imgs torch.Size([4572])
# gt torch.Size([1821])
# residual torch.Size([450])
# imgs torch.Size([4215])
# gt torch.Size([1613])
# residual torch.Size([252])
# imgs torch.Size([4351])
# gt torch.Size([1672])
# residual torch.Size([440])
# imgs torch.Size([4508])
# gt torch.Size([1836])
# residual torch.Size([306])
# imgs torch.Size([4104])
# gt torch.Size([1615])
# residual torch.Size([571])
# imgs torch.Size([4225])
# gt torch.Size([1630])
# residual torch.Size([434])
# imgs torch.Size([4403])
# gt torch.Size([1865])
# residual torch.Size([416])
# imgs torch.Size([4149])
# gt torch.Size([1625])
# residual torch.Size([337])
# imgs torch.Size([4112])
# gt torch.Size([1605])
# residual torch.Size([451])
# imgs torch.Size([4422])
# gt torch.Size([1611])
# residual torch.Size([433])
# imgs torch.Size([4533])
# gt torch.Size([1940])
# residual torch.Size([396])
# imgs torch.Size([4916])
# gt torch.Size([1782])
# residual torch.Size([390])
# imgs torch.Size([4462])
# gt torch.Size([1857])
# residual torch.Size([382])
# imgs torch.Size([4381])
# gt torch.Size([1670])
# residual torch.Size([397])
# imgs torch.Size([3980])
# gt torch.Size([1605])
# residual torch.Size([396])
# imgs torch.Size([4886])
# gt torch.Size([1873])
# residual torch.Size([318])
# imgs torch.Size([4538])
# gt torch.Size([1738])
# residual torch.Size([433])
# imgs torch.Size([4481])
# gt torch.Size([1747])
# residual torch.Size([347])
# imgs torch.Size([4232])
# gt torch.Size([1673])
# residual torch.Size([402])
# imgs torch.Size([4293])
# gt torch.Size([1590])
# residual torch.Size([288])
# imgs torch.Size([4261])
# gt torch.Size([1797])
# residual torch.Size([496])
# imgs torch.Size([4347])
# gt torch.Size([1850])
# residual torch.Size([297])
# imgs torch.Size([4279])
# gt torch.Size([1695])
# residual torch.Size([292])
# imgs torch.Size([4820])
# gt torch.Size([1801])
# residual torch.Size([253])
# imgs torch.Size([4321])
# gt torch.Size([1644])
# residual torch.Size([406])
# imgs torch.Size([4092])
# gt torch.Size([1646])
# residual torch.Size([363])
# imgs torch.Size([4522])
# gt torch.Size([1791])
# residual torch.Size([315])
# imgs torch.Size([4631])
# gt torch.Size([1800])
# residual torch.Size([390])
# imgs torch.Size([4380])
# gt torch.Size([1608])
# residual torch.Size([331])
# imgs torch.Size([4124])
# gt torch.Size([1679])
# residual torch.Size([335])
# imgs torch.Size([4521])
# gt torch.Size([1815])
# residual torch.Size([340])
# imgs torch.Size([4204])
# gt torch.Size([1490])
# residual torch.Size([492])
# imgs torch.Size([4269])
# gt torch.Size([1750])
# residual torch.Size([413])
# imgs torch.Size([4246])
# gt torch.Size([1689])
# residual torch.Size([379])
# imgs torch.Size([3956])
# gt torch.Size([1491])
# residual torch.Size([480])
# imgs torch.Size([4058])
# gt torch.Size([1780])
# residual torch.Size([433])
# imgs torch.Size([4588])
# gt torch.Size([1753])
# residual torch.Size([374])
# imgs torch.Size([4204])
# gt torch.Size([1735])
# residual torch.Size([414])
# imgs torch.Size([4650])
# gt torch.Size([1838])
# residual torch.Size([273])
# imgs torch.Size([4546])
# gt torch.Size([1818])
# residual torch.Size([315])
# imgs torch.Size([4540])
# gt torch.Size([2008])
# residual torch.Size([354])
# imgs torch.Size([4263])
# gt torch.Size([1848])
# residual torch.Size([306])
# imgs torch.Size([4842])
# gt torch.Size([1763])
# residual torch.Size([399])
# imgs torch.Size([3876])
# gt torch.Size([1595])
# residual torch.Size([282])
# imgs torch.Size([4408])
# gt torch.Size([1712])
# residual torch.Size([213])
# imgs torch.Size([4138])
# gt torch.Size([1745])
# residual torch.Size([303])
# imgs torch.Size([4239])
# gt torch.Size([1478])
# residual torch.Size([370])
# imgs torch.Size([4509])
# gt torch.Size([1772])
# residual torch.Size([391])
# imgs torch.Size([4686])
# gt torch.Size([1845])
# residual torch.Size([351])
# imgs torch.Size([4221])
# gt torch.Size([1552])
# residual torch.Size([343])
# imgs torch.Size([4514])
# gt torch.Size([1644])
# residual torch.Size([303])
# imgs torch.Size([4397])
# gt torch.Size([1634])
# residual torch.Size([250])
# imgs torch.Size([4185])
# gt torch.Size([1817])
# residual torch.Size([228])
# imgs torch.Size([4222])
# gt torch.Size([1727])
# residual torch.Size([243])
# imgs torch.Size([3730])
# gt torch.Size([1418])
# residual torch.Size([212])
# imgs torch.Size([4695])
# gt torch.Size([1767])
# residual torch.Size([288])
# imgs torch.Size([4582])
# gt torch.Size([1742])
# residual torch.Size([313])
# imgs torch.Size([4079])
# gt torch.Size([1506])
# residual torch.Size([331])
# imgs torch.Size([4459])
# gt torch.Size([1759])
# residual torch.Size([208])
# imgs torch.Size([4171])
# gt torch.Size([1583])
# residual torch.Size([264])
# imgs torch.Size([4542])
# gt torch.Size([1889])
# residual torch.Size([243])
# imgs torch.Size([4194])
# gt torch.Size([1638])
# residual torch.Size([239])
# imgs torch.Size([4344])
# gt torch.Size([1846])
# residual torch.Size([239])
# imgs torch.Size([4514])
# gt torch.Size([1803])
# residual torch.Size([283])
# imgs torch.Size([3989])
# gt torch.Size([1673])
# residual torch.Size([275])
# imgs torch.Size([4118])
# gt torch.Size([1675])
# residual torch.Size([333])
# imgs torch.Size([4587])
# gt torch.Size([1721])
# residual torch.Size([314])
# imgs torch.Size([4469])
# gt torch.Size([1723])
# residual torch.Size([311])
# imgs torch.Size([4402])
# gt torch.Size([1651])
# residual torch.Size([233])
# imgs torch.Size([4097])
# gt torch.Size([1745])
# residual torch.Size([363])
# imgs torch.Size([4543])
# gt torch.Size([1749])
# residual torch.Size([261])
# imgs torch.Size([4602])
# gt torch.Size([1818])
# residual torch.Size([380])
# imgs torch.Size([4282])
# gt torch.Size([1780])
# residual torch.Size([312])
# imgs torch.Size([4531])
# gt torch.Size([1646])
# residual torch.Size([307])
# imgs torch.Size([4443])
# gt torch.Size([1659])
# residual torch.Size([226])
# imgs torch.Size([4000])
# gt torch.Size([1508])
# residual torch.Size([317])
# imgs torch.Size([4009])
# gt torch.Size([1526])
# residual torch.Size([241])
# imgs torch.Size([4310])
# gt torch.Size([1837])
# residual torch.Size([193])
# imgs torch.Size([3975])
# gt torch.Size([1566])
# residual torch.Size([184])
# imgs torch.Size([4299])
# gt torch.Size([1756])
# residual torch.Size([196])
# imgs torch.Size([4352])
# gt torch.Size([1776])
# residual torch.Size([270])
# imgs torch.Size([4472])
# gt torch.Size([1669])
# residual torch.Size([241])
# imgs torch.Size([4364])
# gt torch.Size([1714])
# residual torch.Size([202])
# imgs torch.Size([4549])
# gt torch.Size([1921])
# residual torch.Size([158])
# imgs torch.Size([4483])
# gt torch.Size([1744])
# residual torch.Size([234])
# imgs torch.Size([4265])
# gt torch.Size([1759])
# residual torch.Size([330])
# imgs torch.Size([4284])
# gt torch.Size([1671])
# residual torch.Size([206])
# imgs torch.Size([4378])
# gt torch.Size([1797])
# residual torch.Size([219])
# imgs torch.Size([4232])
# gt torch.Size([1570])
# residual torch.Size([292])
# imgs torch.Size([4251])
# gt torch.Size([1690])
# residual torch.Size([244])
# imgs torch.Size([4751])
# gt torch.Size([1791])
# residual torch.Size([164])
# imgs torch.Size([4265])
# gt torch.Size([1704])
# residual torch.Size([215])
# imgs torch.Size([4528])
# gt torch.Size([1734])
# residual torch.Size([265])
# imgs torch.Size([4284])
# gt torch.Size([1706])
# residual torch.Size([78])
# imgs torch.Size([4480])
# gt torch.Size([1717])
# residual torch.Size([265])
# imgs torch.Size([4477])
# gt torch.Size([1592])
# residual torch.Size([207])
# imgs torch.Size([4000])
# gt torch.Size([1584])
# residual torch.Size([174])
# imgs torch.Size([4486])
# gt torch.Size([1743])
# residual torch.Size([196])
# imgs torch.Size([4245])
# gt torch.Size([1753])
# residual torch.Size([190])
# imgs torch.Size([4216])
# gt torch.Size([1732])
# residual torch.Size([176])
# imgs torch.Size([4633])
# gt torch.Size([1752])
# residual torch.Size([176])
# imgs torch.Size([4510])
# gt torch.Size([1798])
# residual torch.Size([306])
# imgs torch.Size([4668])
# gt torch.Size([1654])
# residual torch.Size([170])
# imgs torch.Size([4935])
# gt torch.Size([1788])
# residual torch.Size([181])
# imgs torch.Size([4615])
# gt torch.Size([1746])
# residual torch.Size([198])
# imgs torch.Size([3978])
# gt torch.Size([1574])
# residual torch.Size([253])
# imgs torch.Size([4705])
# gt torch.Size([1676])
# residual torch.Size([264])
# imgs torch.Size([4050])
# gt torch.Size([1550])
# residual torch.Size([158])
# imgs torch.Size([4672])
# gt torch.Size([1874])
# residual torch.Size([258])
# imgs torch.Size([4624])
# gt torch.Size([1751])
# residual torch.Size([133])
# imgs torch.Size([4518])
# gt torch.Size([1601])
# residual torch.Size([188])
# imgs torch.Size([5009])
# gt torch.Size([1882])
# residual torch.Size([276])
# imgs torch.Size([4543])
# gt torch.Size([1830])
# residual torch.Size([154])
# imgs torch.Size([4113])
# gt torch.Size([1577])
# residual torch.Size([175])
# imgs torch.Size([4549])
# gt torch.Size([1777])
# residual torch.Size([182])
# imgs torch.Size([4876])
# gt torch.Size([2070])
# residual torch.Size([191])
# imgs torch.Size([4303])
# gt torch.Size([1685])
# residual torch.Size([216])
# imgs torch.Size([4231])
# gt torch.Size([1621])
# residual torch.Size([91])
# imgs torch.Size([4095])
# gt torch.Size([1606])
# residual torch.Size([146])
# imgs torch.Size([4245])
# gt torch.Size([1733])
# residual torch.Size([123])
# imgs torch.Size([4501])
# gt torch.Size([1716])
# residual torch.Size([197])
# imgs torch.Size([4159])
# gt torch.Size([1684])
# residual torch.Size([199])
# imgs torch.Size([4324])
# gt torch.Size([1701])
# residual torch.Size([196])
# imgs torch.Size([4762])
# gt torch.Size([1824])
# residual torch.Size([239])
# imgs torch.Size([4620])
# gt torch.Size([1863])
# residual torch.Size([142])
# imgs torch.Size([4584])
# gt torch.Size([1841])
# residual torch.Size([168])
# imgs torch.Size([4308])
# gt torch.Size([1669])
# residual torch.Size([238])
# imgs torch.Size([4553])
# gt torch.Size([1854])
# residual torch.Size([164])
# imgs torch.Size([4453])
# gt torch.Size([1853])
# residual torch.Size([167])
# imgs torch.Size([4379])
# gt torch.Size([1674])
# residual torch.Size([265])
# imgs torch.Size([4232])
# gt torch.Size([1759])
# residual torch.Size([189])
# imgs torch.Size([4591])
# gt torch.Size([1795])
# residual torch.Size([186])
# imgs torch.Size([4682])
# gt torch.Size([1844])
# residual torch.Size([181])
# imgs torch.Size([4415])
# gt torch.Size([1819])
# residual torch.Size([213])
# imgs torch.Size([4808])
# gt torch.Size([1870])
# residual torch.Size([128])
# imgs torch.Size([4182])
# gt torch.Size([1634])
# residual torch.Size([145])
# imgs torch.Size([4313])
# gt torch.Size([1633])
# residual torch.Size([121])
# imgs torch.Size([4191])
# gt torch.Size([1726])
# residual torch.Size([162])
# imgs torch.Size([4037])
# gt torch.Size([1548])
# residual torch.Size([226])
# imgs torch.Size([4126])
# gt torch.Size([1695])
# residual torch.Size([181])
# imgs torch.Size([4538])
# gt torch.Size([1755])
# residual torch.Size([168])
# imgs torch.Size([4435])
# gt torch.Size([1774])
# residual torch.Size([110])
# imgs torch.Size([4581])
# gt torch.Size([1833])
# residual torch.Size([182])
# imgs torch.Size([4637])
# gt torch.Size([1787])
# residual torch.Size([182])
# imgs torch.Size([4392])
# gt torch.Size([1713])
# residual torch.Size([141])
# imgs torch.Size([3923])
# gt torch.Size([1625])
# residual torch.Size([171])
# imgs torch.Size([4643])
# gt torch.Size([1928])
# residual torch.Size([117])
# imgs torch.Size([4472])
# gt torch.Size([1833])
# residual torch.Size([130])
# imgs torch.Size([4064])
# gt torch.Size([1728])
# residual torch.Size([236])
# imgs torch.Size([4188])
# gt torch.Size([1714])
# residual torch.Size([91])
# imgs torch.Size([4352])
# gt torch.Size([1698])
# residual torch.Size([222])
# imgs torch.Size([4325])
# gt torch.Size([1690])
# residual torch.Size([212])
# imgs torch.Size([4528])
# gt torch.Size([1830])
# residual torch.Size([191])
# imgs torch.Size([4334])
# gt torch.Size([1710])
# residual torch.Size([134])
# imgs torch.Size([4179])
# gt torch.Size([1684])
# residual torch.Size([98])
# imgs torch.Size([4355])
# gt torch.Size([1726])
# residual torch.Size([224])
# imgs torch.Size([4558])
# gt torch.Size([1712])
# residual torch.Size([240])
# imgs torch.Size([4297])
# gt torch.Size([1629])
# residual torch.Size([162])
# imgs torch.Size([4220])
# gt torch.Size([1759])
# residual torch.Size([119])
# imgs torch.Size([4436])
# gt torch.Size([1749])
# residual torch.Size([118])
# imgs torch.Size([4398])
# gt torch.Size([1853])
# residual torch.Size([204])
# imgs torch.Size([4419])
# gt torch.Size([1703])
# residual torch.Size([225])
# imgs torch.Size([4642])
# gt torch.Size([1895])
# residual torch.Size([119])
# imgs torch.Size([4147])
# gt torch.Size([1727])
# residual torch.Size([102])
# imgs torch.Size([4580])
# gt torch.Size([1781])
# residual torch.Size([158])
# imgs torch.Size([4485])
# gt torch.Size([1848])
# residual torch.Size([97])
# imgs torch.Size([3867])
# gt torch.Size([1547])
# residual torch.Size([128])
# imgs torch.Size([4329])
# gt torch.Size([1607])
# residual torch.Size([153])
# imgs torch.Size([4315])
# gt torch.Size([1676])
# residual torch.Size([139])
# imgs torch.Size([4362])
# gt torch.Size([1588])
# residual torch.Size([115])
# imgs torch.Size([4356])
# gt torch.Size([1699])
# residual torch.Size([139])
# imgs torch.Size([4298])
# gt torch.Size([1729])
# residual torch.Size([153])
# imgs torch.Size([4218])
# gt torch.Size([1840])
# residual torch.Size([119])
# imgs torch.Size([4422])
# gt torch.Size([1669])
# residual torch.Size([100])
# imgs torch.Size([4467])
# gt torch.Size([1726])
# residual torch.Size([142])
# imgs torch.Size([4452])
# gt torch.Size([1743])
# residual torch.Size([112])
# imgs torch.Size([4253])
# gt torch.Size([1674])
# residual torch.Size([74])
# imgs torch.Size([4027])
# gt torch.Size([1714])
# residual torch.Size([100])
# imgs torch.Size([4199])
# gt torch.Size([1659])
# residual torch.Size([117])
# imgs torch.Size([4312])
# gt torch.Size([1695])
# residual torch.Size([90])
# imgs torch.Size([4103])
# gt torch.Size([1857])
# residual torch.Size([166])
# imgs torch.Size([4355])
# gt torch.Size([1675])
# residual torch.Size([131])
# imgs torch.Size([4608])
# gt torch.Size([1720])
# residual torch.Size([107])
# imgs torch.Size([4293])
# gt torch.Size([1709])
# residual torch.Size([50])
# imgs torch.Size([4180])
# gt torch.Size([1628])
# residual torch.Size([121])
# imgs torch.Size([4221])
# gt torch.Size([1713])
# residual torch.Size([87])
# imgs torch.Size([4543])
# gt torch.Size([1691])
# residual torch.Size([144])
# imgs torch.Size([4623])
# gt torch.Size([1733])
# residual torch.Size([130])
# imgs torch.Size([4297])
# gt torch.Size([1613])
# residual torch.Size([46])
# imgs torch.Size([4261])
# gt torch.Size([1726])
# residual torch.Size([44])
# imgs torch.Size([4706])
# gt torch.Size([1888])
# residual torch.Size([99])
# imgs torch.Size([3816])
# gt torch.Size([1589])
# residual torch.Size([64])
# imgs torch.Size([4265])
# gt torch.Size([1657])
# residual torch.Size([121])
# imgs torch.Size([4005])
# gt torch.Size([1588])
# residual torch.Size([87])
# imgs torch.Size([4229])
# gt torch.Size([1713])
# residual torch.Size([100])
# imgs torch.Size([4585])
# gt torch.Size([1879])
# residual torch.Size([104])
# imgs torch.Size([4272])
# gt torch.Size([1751])
# residual torch.Size([122])
# imgs torch.Size([4353])
# gt torch.Size([1642])
# residual torch.Size([83])
# imgs torch.Size([4169])
# gt torch.Size([1860])
# residual torch.Size([106])
# imgs torch.Size([4855])
# gt torch.Size([1890])
# residual torch.Size([62])
# imgs torch.Size([4177])
# gt torch.Size([1656])
# residual torch.Size([109])
# imgs torch.Size([4375])
# gt torch.Size([1882])
# residual torch.Size([115])
# imgs torch.Size([4583])
# gt torch.Size([1976])
# residual torch.Size([85])
# imgs torch.Size([4419])
# gt torch.Size([1788])
# residual torch.Size([93])
# imgs torch.Size([3984])
# gt torch.Size([1536])
# residual torch.Size([75])
# imgs torch.Size([4200])
# gt torch.Size([1574])
# residual torch.Size([108])
# imgs torch.Size([4486])
# gt torch.Size([1754])
# residual torch.Size([67])
# imgs torch.Size([4170])
# gt torch.Size([1672])
# residual torch.Size([103])
# imgs torch.Size([4209])
# gt torch.Size([1615])
# residual torch.Size([66])
# imgs torch.Size([4362])
# gt torch.Size([1583])
# residual torch.Size([126])
# imgs torch.Size([4361])
# gt torch.Size([1695])
# residual torch.Size([44])
# imgs torch.Size([4444])
# gt torch.Size([1694])
# residual torch.Size([107])
# imgs torch.Size([4183])
# gt torch.Size([1805])
# residual torch.Size([83])
# imgs torch.Size([4269])
# gt torch.Size([1560])
# residual torch.Size([74])
# imgs torch.Size([4493])
# gt torch.Size([1663])
# residual torch.Size([69])
# imgs torch.Size([4414])
# gt torch.Size([1725])
# residual torch.Size([107])
# imgs torch.Size([4341])
# gt torch.Size([1797])
# residual torch.Size([90])
# imgs torch.Size([4333])
# gt torch.Size([1742])
# residual torch.Size([97])
# imgs torch.Size([4255])
# gt torch.Size([1695])
# residual torch.Size([184])
# imgs torch.Size([4306])
# gt torch.Size([1668])
# residual torch.Size([48])
# imgs torch.Size([4453])
# gt torch.Size([1779])
# residual torch.Size([99])
# imgs torch.Size([4421])
# gt torch.Size([1796])
# residual torch.Size([113])
# imgs torch.Size([4178])
# gt torch.Size([1596])
# residual torch.Size([144])
# imgs torch.Size([4754])
# gt torch.Size([1918])
# residual torch.Size([147])
# imgs torch.Size([4390])
# gt torch.Size([1724])
# residual torch.Size([56])
# imgs torch.Size([4730])
# gt torch.Size([1764])
# residual torch.Size([91])
# imgs torch.Size([4539])
# gt torch.Size([1940])
# residual torch.Size([122])
# imgs torch.Size([4375])
# gt torch.Size([1798])
# residual torch.Size([72])
# imgs torch.Size([4798])
# gt torch.Size([1863])
# residual torch.Size([83])
# imgs torch.Size([4398])
# gt torch.Size([1641])
# residual torch.Size([106])
# imgs torch.Size([4343])
# gt torch.Size([1810])
# residual torch.Size([97])
# imgs torch.Size([4470])
# gt torch.Size([1522])
# residual torch.Size([62])
# imgs torch.Size([4579])
# gt torch.Size([1675])
# residual torch.Size([88])
# imgs torch.Size([3823])
# gt torch.Size([1477])
# residual torch.Size([80])
# imgs torch.Size([4233])
# gt torch.Size([1599])
# residual torch.Size([113])
# imgs torch.Size([4386])
# gt torch.Size([1660])
# residual torch.Size([130])
# imgs torch.Size([4395])
# gt torch.Size([1833])
# residual torch.Size([82])
# imgs torch.Size([4655])
# gt torch.Size([2010])
# residual torch.Size([63])
# imgs torch.Size([4487])
# gt torch.Size([1741])
# residual torch.Size([85])
# imgs torch.Size([4112])
# gt torch.Size([1671])
# residual torch.Size([76])
# imgs torch.Size([4211])
# gt torch.Size([1571])
# residual torch.Size([34])
# imgs torch.Size([4575])
# gt torch.Size([1988])
# residual torch.Size([128])
# imgs torch.Size([4187])
# gt torch.Size([1566])
# residual torch.Size([101])
# imgs torch.Size([4180])
# gt torch.Size([1762])
# residual torch.Size([43])
# imgs torch.Size([4348])
# gt torch.Size([1611])
# residual torch.Size([67])
# imgs torch.Size([4489])
# gt torch.Size([1820])
# residual torch.Size([81])
# imgs torch.Size([4496])
# gt torch.Size([1730])
# residual torch.Size([75])
# imgs torch.Size([4474])
# gt torch.Size([1705])
# residual torch.Size([113])
# imgs torch.Size([4027])
# gt torch.Size([1628])
# residual torch.Size([61])
# imgs torch.Size([4283])
# gt torch.Size([1778])
# residual torch.Size([103])
# imgs torch.Size([4587])
# gt torch.Size([1763])
# residual torch.Size([31])
# imgs torch.Size([4237])
# gt torch.Size([1571])
# residual torch.Size([78])
# imgs torch.Size([4548])
# gt torch.Size([1788])
# residual torch.Size([76])
# imgs torch.Size([4397])
# gt torch.Size([1623])
# residual torch.Size([54])
# imgs torch.Size([5189])
# gt torch.Size([2052])
# residual torch.Size([30])
# imgs torch.Size([4093])
# gt torch.Size([1616])
# residual torch.Size([106])
# imgs torch.Size([4506])
# gt torch.Size([1769])
# residual torch.Size([64])
# imgs torch.Size([4138])
# gt torch.Size([1727])
# residual torch.Size([71])
# imgs torch.Size([4404])
# gt torch.Size([1591])
# residual torch.Size([106])
# imgs torch.Size([4185])
# gt torch.Size([1596])
# residual torch.Size([66])
# imgs torch.Size([4273])
# gt torch.Size([1850])
# residual torch.Size([61])
# imgs torch.Size([4345])
# gt torch.Size([1719])
# residual torch.Size([52])
# imgs torch.Size([3998])
# gt torch.Size([1535])
# residual torch.Size([37])
# imgs torch.Size([4715])
# gt torch.Size([1806])
# residual torch.Size([59])
# imgs torch.Size([4377])
# gt torch.Size([1790])
# residual torch.Size([37])
# imgs torch.Size([4061])
# gt torch.Size([1634])
# residual torch.Size([47])
# imgs torch.Size([4624])
# gt torch.Size([1672])
# residual torch.Size([46])
# imgs torch.Size([4455])
# gt torch.Size([1724])
# residual torch.Size([47])
# imgs torch.Size([4407])
# gt torch.Size([1729])
# residual torch.Size([33])
# imgs torch.Size([4240])
# gt torch.Size([1565])
# residual torch.Size([59])
# imgs torch.Size([3479])
# gt torch.Size([1355])
# residual torch.Size([50])
# imgs torch.Size([4428])
# gt torch.Size([1814])
# residual torch.Size([58])
# imgs torch.Size([4515])
# gt torch.Size([1819])
# residual torch.Size([35])
# imgs torch.Size([4421])
# gt torch.Size([1924])
# residual torch.Size([70])
# imgs torch.Size([4325])
# gt torch.Size([1675])
# residual torch.Size([92])
# imgs torch.Size([4337])
# gt torch.Size([1681])
# residual torch.Size([46])
# imgs torch.Size([4253])
# gt torch.Size([1696])
# residual torch.Size([85])
# imgs torch.Size([4416])
# gt torch.Size([1766])
# residual torch.Size([37])
# imgs torch.Size([4128])
# gt torch.Size([1768])
# residual torch.Size([49])
# imgs torch.Size([4437])
# gt torch.Size([1716])
# residual torch.Size([99])
# imgs torch.Size([4712])
# gt torch.Size([1905])
# residual torch.Size([29])
# imgs torch.Size([4462])
# gt torch.Size([1580])
# residual torch.Size([42])
# imgs torch.Size([4544])
# gt torch.Size([1688])
# residual torch.Size([42])
# imgs torch.Size([3776])
# gt torch.Size([1405])
# residual torch.Size([46])
# imgs torch.Size([4511])
# gt torch.Size([1701])
# residual torch.Size([100])
# imgs torch.Size([4440])
# gt torch.Size([1737])
# residual torch.Size([12])
# imgs torch.Size([4325])
# gt torch.Size([1671])
# residual torch.Size([67])
# imgs torch.Size([4014])
# gt torch.Size([1588])
# residual torch.Size([42])
# imgs torch.Size([4749])
# gt torch.Size([1877])
# residual torch.Size([62])
# imgs torch.Size([4560])
# gt torch.Size([1778])
# residual torch.Size([42])
# imgs torch.Size([4354])
# gt torch.Size([1650])
# residual torch.Size([57])
# imgs torch.Size([4257])
# gt torch.Size([1543])
# residual torch.Size([56])
# imgs torch.Size([4117])
# gt torch.Size([1639])
# residual torch.Size([48])
# imgs torch.Size([4245])
# gt torch.Size([1629])
# residual torch.Size([52])
# imgs torch.Size([4635])
# gt torch.Size([1845])
# residual torch.Size([56])
# imgs torch.Size([4327])
# gt torch.Size([1696])
# residual torch.Size([93])
# imgs torch.Size([3930])
# gt torch.Size([1451])
# residual torch.Size([55])
# imgs torch.Size([4674])
# gt torch.Size([1865])
# residual torch.Size([44])
# imgs torch.Size([4480])
# gt torch.Size([1727])
# residual torch.Size([62])
# imgs torch.Size([4097])
# gt torch.Size([1515])
# residual torch.Size([47])
# imgs torch.Size([4415])
# gt torch.Size([1729])
# residual torch.Size([57])
# imgs torch.Size([4303])
# gt torch.Size([1676])
# residual torch.Size([36])
# imgs torch.Size([4178])
# gt torch.Size([1849])
# residual torch.Size([31])
# imgs torch.Size([4420])
# gt torch.Size([1685])
# residual torch.Size([41])
# imgs torch.Size([3964])
# gt torch.Size([1432])
# residual torch.Size([66])
# imgs torch.Size([4293])
# gt torch.Size([1806])
# residual torch.Size([47])
# imgs torch.Size([4035])
# gt torch.Size([1467])
# residual torch.Size([35])
# imgs torch.Size([4589])
# gt torch.Size([1875])
# residual torch.Size([52])
# imgs torch.Size([4467])
# gt torch.Size([1792])
# residual torch.Size([37])
# imgs torch.Size([4753])
# gt torch.Size([1852])
# residual torch.Size([79])
# imgs torch.Size([4254])
# gt torch.Size([1725])
# residual torch.Size([51])
# imgs torch.Size([4629])
# gt torch.Size([1827])
# residual torch.Size([19])
# imgs torch.Size([4573])
# gt torch.Size([1949])
# residual torch.Size([15])
# imgs torch.Size([4398])
# gt torch.Size([1803])
# residual torch.Size([60])
# imgs torch.Size([4414])
# gt torch.Size([1522])
# residual torch.Size([39])
# imgs torch.Size([4472])
# gt torch.Size([1768])
# residual torch.Size([38])
# imgs torch.Size([4460])
# gt torch.Size([1517])
# residual torch.Size([25])
# imgs torch.Size([4337])
# gt torch.Size([1684])
# residual torch.Size([42])
# imgs torch.Size([4529])
# gt torch.Size([1913])
# residual torch.Size([41])
# imgs torch.Size([4477])
# gt torch.Size([1765])
# residual torch.Size([35])
# imgs torch.Size([4393])
# gt torch.Size([1789])
# residual torch.Size([29])
# imgs torch.Size([4439])
# gt torch.Size([1851])
# residual torch.Size([49])
# imgs torch.Size([4251])
# gt torch.Size([1677])
# residual torch.Size([40])
# imgs torch.Size([4523])
# gt torch.Size([1763])
# residual torch.Size([28])
# imgs torch.Size([4563])
# gt torch.Size([1800])
# residual torch.Size([25])
# imgs torch.Size([4335])
# gt torch.Size([1717])
# residual torch.Size([14])
# imgs torch.Size([4433])
# gt torch.Size([1591])
# residual torch.Size([67])
# imgs torch.Size([4835])
# gt torch.Size([1981])
# residual torch.Size([62])
# imgs torch.Size([4514])
# gt torch.Size([1957])
# residual torch.Size([54])
# imgs torch.Size([4252])
# gt torch.Size([1685])
# residual torch.Size([49])
# imgs torch.Size([4386])
# gt torch.Size([1688])
# residual torch.Size([32])
# imgs torch.Size([3905])
# gt torch.Size([1592])
# residual torch.Size([49])
# imgs torch.Size([4387])
# gt torch.Size([1824])
# residual torch.Size([25])
# imgs torch.Size([4100])
# gt torch.Size([1628])
# residual torch.Size([31])
# imgs torch.Size([4790])
# gt torch.Size([1777])
# residual torch.Size([47])
# imgs torch.Size([4099])
# gt torch.Size([1571])
# residual torch.Size([23])
# imgs torch.Size([4373])
# gt torch.Size([1734])
# residual torch.Size([33])
# imgs torch.Size([4838])
# gt torch.Size([1759])
# residual torch.Size([39])
# imgs torch.Size([4030])
# gt torch.Size([1754])
# residual torch.Size([39])
# imgs torch.Size([4031])
# gt torch.Size([1606])
# residual torch.Size([39])
# imgs torch.Size([4274])
# gt torch.Size([1874])
# residual torch.Size([45])
# imgs torch.Size([4495])
# gt torch.Size([1896])
# residual torch.Size([25])
# imgs torch.Size([4273])
# gt torch.Size([1750])
# residual torch.Size([60])
# imgs torch.Size([4148])
# gt torch.Size([1613])
# residual torch.Size([19])
# imgs torch.Size([4194])
# gt torch.Size([1739])
# residual torch.Size([31])
# imgs torch.Size([4208])
# gt torch.Size([1838])
# residual torch.Size([42])
# imgs torch.Size([4438])
# gt torch.Size([1727])
# residual torch.Size([46])
# imgs torch.Size([4313])
# gt torch.Size([1739])
# residual torch.Size([30])
# imgs torch.Size([4637])
# gt torch.Size([1860])
# residual torch.Size([45])
# imgs torch.Size([4069])
# gt torch.Size([1661])
# residual torch.Size([37])
# imgs torch.Size([4850])
# gt torch.Size([1875])
# residual torch.Size([48])
# imgs torch.Size([4089])
# gt torch.Size([1574])
# residual torch.Size([30])
# imgs torch.Size([4079])
# gt torch.Size([1798])
# residual torch.Size([35])
# imgs torch.Size([4896])
# gt torch.Size([1798])
# residual torch.Size([66])
# imgs torch.Size([4309])
# gt torch.Size([1572])
# residual torch.Size([42])
# imgs torch.Size([4379])
# gt torch.Size([1845])
# residual torch.Size([32])
# imgs torch.Size([4640])
# gt torch.Size([1685])
# residual torch.Size([44])
# imgs torch.Size([4362])
# gt torch.Size([1678])
# residual torch.Size([57])
# imgs torch.Size([4717])
# gt torch.Size([1864])
# residual torch.Size([37])
# imgs torch.Size([4288])
# gt torch.Size([1677])
# residual torch.Size([19])
# imgs torch.Size([4203])
# gt torch.Size([1567])
# residual torch.Size([74])
# imgs torch.Size([4611])
# gt torch.Size([1755])
# residual torch.Size([31])
# imgs torch.Size([4412])
# gt torch.Size([1704])
# residual torch.Size([33])
# imgs torch.Size([4030])
# gt torch.Size([1730])
# residual torch.Size([69])
# imgs torch.Size([4194])
# gt torch.Size([1681])
# residual torch.Size([55])
# imgs torch.Size([4091])
# gt torch.Size([1703])
# residual torch.Size([14])
# imgs torch.Size([4258])
# gt torch.Size([1643])
# residual torch.Size([82])
# imgs torch.Size([4392])
# gt torch.Size([1702])
# residual torch.Size([13])
# imgs torch.Size([4195])
# gt torch.Size([1745])
# residual torch.Size([28])
# imgs torch.Size([4502])
# gt torch.Size([1666])
# residual torch.Size([15])
# imgs torch.Size([4106])
# gt torch.Size([1569])
# residual torch.Size([13])
# imgs torch.Size([4519])
# gt torch.Size([1856])
# residual torch.Size([43])
# imgs torch.Size([4175])
# gt torch.Size([1700])
# residual torch.Size([70])
# imgs torch.Size([4193])
# gt torch.Size([1740])
# residual torch.Size([37])
# imgs torch.Size([4366])
# gt torch.Size([1595])
# residual torch.Size([8])
# imgs torch.Size([4168])
# gt torch.Size([1667])
# residual torch.Size([57])
# imgs torch.Size([4651])
# gt torch.Size([1723])
# residual torch.Size([25])
# imgs torch.Size([4399])
# gt torch.Size([1852])
# residual torch.Size([27])
# imgs torch.Size([4868])
# gt torch.Size([1769])
# residual torch.Size([38])
# imgs torch.Size([4797])
# gt torch.Size([1699])
# residual torch.Size([39])
# imgs torch.Size([4261])
# gt torch.Size([1591])
# residual torch.Size([40])
# imgs torch.Size([4216])
# gt torch.Size([1682])
# residual torch.Size([27])
# imgs torch.Size([4181])
# gt torch.Size([1643])
# residual torch.Size([27])
# imgs torch.Size([4307])
# gt torch.Size([1717])
# ...
# imgs torch.Size([4698])
# gt torch.Size([1771])
# residual torch.Size([0])
# imgs torch.Size([4257])
# gt torch.Size([1709])
# residual torch.Size([0])
# imgs torch.Size([4384])
# gt torch.Size([1911])
# residual torch.Size([0])
# imgs torch.Size([4386])
# gt torch.Size([1727])
# residual torch.Size([0])
# imgs torch.Size([4085])
# gt torch.Size([1735])
# residual torch.Size([0])
# imgs torch.Size([4136])
# gt torch.Size([1732])
# residual torch.Size([0])
# imgs torch.Size([4932])
# gt torch.Size([1875])
# residual torch.Size([0])
# imgs torch.Size([4338])
# gt torch.Size([1658])
# residual torch.Size([0])
# imgs torch.Size([4423])
# gt torch.Size([1801])
# residual torch.Size([0])
# imgs torch.Size([4287])
# gt torch.Size([1769])
# residual torch.Size([0])
# imgs torch.Size([4087])
# gt torch.Size([1712])
# residual torch.Size([0])
# imgs torch.Size([4636])
# gt torch.Size([1693])
# residual torch.Size([0])
# imgs torch.Size([4413])
# gt torch.Size([1753])
# residual torch.Size([0])
# imgs torch.Size([4500])
# gt torch.Size([1538])
# residual torch.Size([0])
# imgs torch.Size([4738])
# gt torch.Size([1835])
# residual torch.Size([0])
# imgs torch.Size([4430])
# gt torch.Size([1742])
# residual torch.Size([0])
# imgs torch.Size([4286])
# gt torch.Size([1840])
# residual torch.Size([0])
# imgs torch.Size([4343])
# gt torch.Size([1684])
# residual torch.Size([0])
# imgs torch.Size([4078])
# gt torch.Size([1589])
# residual torch.Size([0])
# imgs torch.Size([4353])
# gt torch.Size([1748])
# residual torch.Size([0])
# imgs torch.Size([4595])
# gt torch.Size([1841])
# residual torch.Size([0])
# imgs torch.Size([4212])
# gt torch.Size([1681])
# residual torch.Size([0])
# imgs torch.Size([4615])
# gt torch.Size([1713])
# residual torch.Size([0])
# imgs torch.Size([4643])
# gt torch.Size([1822])
# residual torch.Size([0])
# imgs torch.Size([4365])
# gt torch.Size([1652])
# residual torch.Size([0])
# imgs torch.Size([4632])
# gt torch.Size([1793])
# residual torch.Size([0])
# imgs torch.Size([4422])
# gt torch.Size([1721])
# residual torch.Size([0])
# imgs torch.Size([4234])
# gt torch.Size([1588])
# residual torch.Size([0])
# imgs torch.Size([4535])
# gt torch.Size([1796])
# residual torch.Size([0])
# imgs torch.Size([4244])
# gt torch.Size([1785])
# residual torch.Size([0])
# imgs torch.Size([4271])
# gt torch.Size([1550])
# residual torch.Size([0])
# imgs torch.Size([4400])
# gt torch.Size([1725])
# residual torch.Size([0])
# imgs torch.Size([4331])
# gt torch.Size([1768])
# residual torch.Size([0])
# imgs torch.Size([4104])
# gt torch.Size([1639])
# residual torch.Size([0])
# imgs torch.Size([4484])
# gt torch.Size([1709])
# residual torch.Size([0])
# imgs torch.Size([4818])
# gt torch.Size([1809])
# residual torch.Size([0])
# imgs torch.Size([4466])
# gt torch.Size([1646])
# residual torch.Size([0])
# imgs torch.Size([4175])
# gt torch.Size([1634])
# residual torch.Size([0])
# imgs torch.Size([4270])
# gt torch.Size([1727])
# residual torch.Size([0])
# imgs torch.Size([4234])
# gt torch.Size([1598])
# residual torch.Size([0])
# imgs torch.Size([4516])
# gt torch.Size([1815])
# residual torch.Size([0])
# imgs torch.Size([4314])
# gt torch.Size([1761])
# residual torch.Size([0])
# imgs torch.Size([4198])
# gt torch.Size([1589])
# residual torch.Size([0])
# imgs torch.Size([4343])
# gt torch.Size([1506])
# residual torch.Size([0])
# imgs torch.Size([3997])
# gt torch.Size([1636])
# residual torch.Size([0])
# imgs torch.Size([3948])
# gt torch.Size([1546])
# residual torch.Size([0])
# imgs torch.Size([4657])
# gt torch.Size([1779])
# residual torch.Size([0])
# imgs torch.Size([4815])
# gt torch.Size([1763])
# residual torch.Size([0])
# imgs torch.Size([4388])
# gt torch.Size([1739])
# residual torch.Size([0])
# imgs torch.Size([4470])
# gt torch.Size([1699])
# residual torch.Size([0])
# imgs torch.Size([3843])
# gt torch.Size([1599])
# residual torch.Size([0])
# imgs torch.Size([4477])
# gt torch.Size([1873])
# residual torch.Size([0])
# imgs torch.Size([4338])
# gt torch.Size([1746])
# residual torch.Size([0])
# imgs torch.Size([4299])
# gt torch.Size([1711])
# residual torch.Size([0])
# imgs torch.Size([4777])
# gt torch.Size([1826])
# residual torch.Size([0])
# imgs torch.Size([4681])
# gt torch.Size([1855])
# residual torch.Size([0])
# imgs torch.Size([4368])
# gt torch.Size([1669])
# residual torch.Size([0])
# imgs torch.Size([4887])
# gt torch.Size([1625])
# residual torch.Size([0])
# imgs torch.Size([4624])
# gt torch.Size([1916])
# residual torch.Size([0])
# imgs torch.Size([4447])
# gt torch.Size([1916])
# residual torch.Size([0])
# imgs torch.Size([4134])
# gt torch.Size([1763])
# residual torch.Size([0])
# imgs torch.Size([4441])
# gt torch.Size([1760])
# residual torch.Size([0])
# imgs torch.Size([4163])
# gt torch.Size([1635])
# residual torch.Size([0])
# imgs torch.Size([3646])
# gt torch.Size([1458])
# residual torch.Size([0])
# imgs torch.Size([4333])
# gt torch.Size([1731])
# residual torch.Size([0])
# imgs torch.Size([4583])
# gt torch.Size([1767])
# residual torch.Size([0])
# imgs torch.Size([4538])
# gt torch.Size([1662])
# residual torch.Size([0])
# imgs torch.Size([4324])
# gt torch.Size([1796])
# residual torch.Size([0])
# imgs torch.Size([4082])
# gt torch.Size([1547])
# residual torch.Size([0])
# imgs torch.Size([4249])
# gt torch.Size([1622])
# residual torch.Size([0])
# imgs torch.Size([4424])
# gt torch.Size([1649])
# residual torch.Size([0])
# imgs torch.Size([3993])
# gt torch.Size([1509])
# residual torch.Size([0])
# imgs torch.Size([4694])
# gt torch.Size([1753])
# residual torch.Size([0])
# imgs torch.Size([4510])
# gt torch.Size([1651])
# residual torch.Size([0])
# imgs torch.Size([4337])
# gt torch.Size([1584])
# residual torch.Size([0])
# imgs torch.Size([4315])
# gt torch.Size([1767])
# residual torch.Size([0])
# imgs torch.Size([4471])
# gt torch.Size([1883])
# residual torch.Size([0])
# imgs torch.Size([3972])
# gt torch.Size([1517])
# residual torch.Size([0])
# imgs torch.Size([4190])
# gt torch.Size([1754])
# residual torch.Size([0])
# imgs torch.Size([4243])
# gt torch.Size([1506])
# residual torch.Size([0])
# imgs torch.Size([3953])
# gt torch.Size([1510])
# residual torch.Size([0])
# imgs torch.Size([4315])
# gt torch.Size([1673])
# residual torch.Size([0])
# imgs torch.Size([4590])
# gt torch.Size([1720])
# residual torch.Size([0])
# imgs torch.Size([4554])
# gt torch.Size([1620])
# residual torch.Size([0])
# imgs torch.Size([4579])
# gt torch.Size([1921])
# residual torch.Size([0])
# imgs torch.Size([4362])
# gt torch.Size([1704])
# residual torch.Size([0])
# imgs torch.Size([4577])
# gt torch.Size([1843])
# residual torch.Size([0])
# imgs torch.Size([4362])
# gt torch.Size([1818])
# residual torch.Size([0])
# imgs torch.Size([4123])
# gt torch.Size([1587])
# residual torch.Size([0])
# imgs torch.Size([4541])
# gt torch.Size([1530])
# residual torch.Size([0])
# imgs torch.Size([4237])
# gt torch.Size([1718])
# residual torch.Size([0])
# imgs torch.Size([4460])
# gt torch.Size([1863])
# residual torch.Size([0])
# imgs torch.Size([4253])
# gt torch.Size([1693])
# residual torch.Size([0])
# imgs torch.Size([4301])
# gt torch.Size([1633])
# residual torch.Size([0])
# imgs torch.Size([4668])
# gt torch.Size([1656])
# residual torch.Size([0])
# imgs torch.Size([4456])
# gt torch.Size([1747])
# residual torch.Size([0])
# imgs torch.Size([4459])
# gt torch.Size([1703])
# residual torch.Size([0])
# imgs torch.Size([4446])
# gt torch.Size([1795])
# residual torch.Size([0])
# imgs torch.Size([4574])
# gt torch.Size([1787])
# residual torch.Size([0])
# imgs torch.Size([4536])
# gt torch.Size([1855])
# residual torch.Size([0])
# imgs torch.Size([4412])
# gt torch.Size([1605])
# residual torch.Size([0])
# imgs torch.Size([4296])
# gt torch.Size([1656])
# residual torch.Size([0])
# imgs torch.Size([4244])
# gt torch.Size([1778])
# residual torch.Size([0])
# imgs torch.Size([4216])
# gt torch.Size([1561])
# residual torch.Size([0])
# imgs torch.Size([4418])
# gt torch.Size([1737])
# residual torch.Size([0])
# imgs torch.Size([4528])
# gt torch.Size([1701])
# residual torch.Size([0])
# imgs torch.Size([4273])
# gt torch.Size([1612])
# residual torch.Size([0])
# imgs torch.Size([4171])
# gt torch.Size([1462])
# residual torch.Size([0])
# imgs torch.Size([2284])
# gt torch.Size([796])
# residual torch.Size([0])
# Images from epoch 2
# shapes im torch.Size([16, 1, 28, 28])
# shapes O1 torch.Size([16, 1, 28, 28])
# Epoch 3/10  Loss: 11.7022
# imgs torch.Size([4137])
# gt torch.Size([1769])
# residual torch.Size([0])
# imgs torch.Size([4485])
# gt torch.Size([1787])
# residual torch.Size([0])
# imgs torch.Size([4616])
# gt torch.Size([1782])
# residual torch.Size([0])
# imgs torch.Size([4480])
# gt torch.Size([1916])
# residual torch.Size([0])
# imgs torch.Size([4293])
# gt torch.Size([1702])
# residual torch.Size([0])
# imgs torch.Size([4647])
# gt torch.Size([1943])
# residual torch.Size([0])
# imgs torch.Size([4569])
# gt torch.Size([1906])
# residual torch.Size([0])
# imgs torch.Size([4721])
# gt torch.Size([1637])
# residual torch.Size([0])
# imgs torch.Size([4425])
# gt torch.Size([1757])
# residual torch.Size([0])
# imgs torch.Size([4500])
# gt torch.Size([1801])
# residual torch.Size([0])
# imgs torch.Size([4324])
# gt torch.Size([1677])
# residual torch.Size([0])
# imgs torch.Size([4320])
# gt torch.Size([1857])
# residual torch.Size([0])
# imgs torch.Size([4198])
# gt torch.Size([1470])
# residual torch.Size([0])
# imgs torch.Size([4782])
# gt torch.Size([1760])
# residual torch.Size([0])
# imgs torch.Size([3956])
# gt torch.Size([1474])
# residual torch.Size([0])
# imgs torch.Size([4420])
# gt torch.Size([1662])
# residual torch.Size([0])
# imgs torch.Size([4268])
# gt torch.Size([1644])
# residual torch.Size([0])
# imgs torch.Size([4421])
# gt torch.Size([1794])
# residual torch.Size([0])
# imgs torch.Size([4200])
# gt torch.Size([1664])
# residual torch.Size([0])
# imgs torch.Size([4690])
# gt torch.Size([1967])
# residual torch.Size([0])
# imgs torch.Size([4243])
# gt torch.Size([1817])
# residual torch.Size([0])
# imgs torch.Size([4322])
# gt torch.Size([1679])
# residual torch.Size([0])
# imgs torch.Size([4059])
# gt torch.Size([1592])
# residual torch.Size([0])
# imgs torch.Size([4739])
# gt torch.Size([1771])
# residual torch.Size([0])
# imgs torch.Size([4509])
# gt torch.Size([1914])
# residual torch.Size([0])
# imgs torch.Size([4439])
# gt torch.Size([1728])
# residual torch.Size([0])
# imgs torch.Size([4152])
# gt torch.Size([1801])
# residual torch.Size([0])
# imgs torch.Size([4331])
# gt torch.Size([1784])
# residual torch.Size([0])
# imgs torch.Size([4463])
# gt torch.Size([1692])
# residual torch.Size([0])
# imgs torch.Size([4430])
# gt torch.Size([1767])
# residual torch.Size([0])
# imgs torch.Size([4211])
# gt torch.Size([1744])
# residual torch.Size([0])
# imgs torch.Size([4301])
# gt torch.Size([1642])
# residual torch.Size([0])
# imgs torch.Size([4106])
# gt torch.Size([1591])
# residual torch.Size([0])
# imgs torch.Size([4361])
# gt torch.Size([1791])
# residual torch.Size([0])
# imgs torch.Size([4644])
# gt torch.Size([1884])
# residual torch.Size([0])
# imgs torch.Size([4123])
# gt torch.Size([1609])
# residual torch.Size([0])
# imgs torch.Size([4548])
# gt torch.Size([1750])
# residual torch.Size([0])
# imgs torch.Size([4301])
# gt torch.Size([1735])
# residual torch.Size([0])
# imgs torch.Size([4631])
# gt torch.Size([1786])
# residual torch.Size([0])
# imgs torch.Size([4515])
# gt torch.Size([1772])
# residual torch.Size([0])
# imgs torch.Size([4280])
# gt torch.Size([1666])
# residual torch.Size([0])
# imgs torch.Size([4335])
# gt torch.Size([1728])
# residual torch.Size([0])
# imgs torch.Size([4308])
# gt torch.Size([1578])
# residual torch.Size([0])
# imgs torch.Size([4463])
# gt torch.Size([1852])
# residual torch.Size([0])
# imgs torch.Size([4352])
# gt torch.Size([1590])
# residual torch.Size([0])
# imgs torch.Size([4530])
# gt torch.Size([1683])
# residual torch.Size([0])
# imgs torch.Size([4659])
# gt torch.Size([1865])
# residual torch.Size([0])
# imgs torch.Size([4436])
# gt torch.Size([1871])
# residual torch.Size([0])
# imgs torch.Size([4206])
# gt torch.Size([1775])
# residual torch.Size([0])
# imgs torch.Size([4604])
# gt torch.Size([1879])
# residual torch.Size([0])
# imgs torch.Size([4373])
# gt torch.Size([1738])
# residual torch.Size([0])
# imgs torch.Size([4246])
# gt torch.Size([1660])
# residual torch.Size([0])
# imgs torch.Size([4275])
# gt torch.Size([1775])
# residual torch.Size([0])
# imgs torch.Size([4493])
# gt torch.Size([1648])
# residual torch.Size([0])
# imgs torch.Size([4427])
# gt torch.Size([1818])
# residual torch.Size([0])
# imgs torch.Size([4431])
# gt torch.Size([1723])
# residual torch.Size([0])
# imgs torch.Size([4855])
# gt torch.Size([1648])
# residual torch.Size([0])
# imgs torch.Size([4725])
# gt torch.Size([1809])
# residual torch.Size([0])
# imgs torch.Size([4040])
# gt torch.Size([1509])
# residual torch.Size([0])
# imgs torch.Size([4580])
# gt torch.Size([1776])
# residual torch.Size([0])
# imgs torch.Size([4910])
# gt torch.Size([2057])
# residual torch.Size([0])
# imgs torch.Size([4451])
# gt torch.Size([1669])
# residual torch.Size([0])
# imgs torch.Size([3979])
# gt torch.Size([1666])
# residual torch.Size([0])
# imgs torch.Size([4587])
# gt torch.Size([1673])
# residual torch.Size([0])
# imgs torch.Size([4369])
# gt torch.Size([1725])
# residual torch.Size([0])
# imgs torch.Size([4243])
# gt torch.Size([1746])
# residual torch.Size([0])
# imgs torch.Size([4375])
# gt torch.Size([1795])
# residual torch.Size([0])
# imgs torch.Size([4027])
# gt torch.Size([1556])
# residual torch.Size([0])
# imgs torch.Size([4648])
# gt torch.Size([1745])
# residual torch.Size([0])
# imgs torch.Size([4279])
# gt torch.Size([1743])
# residual torch.Size([0])
# imgs torch.Size([4485])
# gt torch.Size([1841])
# residual torch.Size([0])
# imgs torch.Size([4488])
# gt torch.Size([1911])
# residual torch.Size([0])
# imgs torch.Size([4168])
# gt torch.Size([1431])
# residual torch.Size([0])
# imgs torch.Size([4616])
# gt torch.Size([1872])
# residual torch.Size([0])
# imgs torch.Size([4293])
# gt torch.Size([1743])
# residual torch.Size([0])
# imgs torch.Size([4492])
# gt torch.Size([1816])
# residual torch.Size([0])
# imgs torch.Size([4646])
# gt torch.Size([1794])
# residual torch.Size([0])
# imgs torch.Size([4304])
# gt torch.Size([1715])
# residual torch.Size([0])
# imgs torch.Size([4674])
# gt torch.Size([1947])
# residual torch.Size([0])
# imgs torch.Size([4002])
# gt torch.Size([1648])
# residual torch.Size([0])
# imgs torch.Size([4777])
# gt torch.Size([1784])
# residual torch.Size([0])
# imgs torch.Size([4486])
# gt torch.Size([1748])
# residual torch.Size([0])
# imgs torch.Size([4731])
# gt torch.Size([1760])
# residual torch.Size([0])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 27
#      23 vae1.eval()
#      25 vae2 = VAE2(latent_dim=config['latent_dim'], patch_size=config['patch_size']).to(device)
# ---> 27 train_vae2(vae1, vae2, train_loader, config, device)
#
# Cell In[18], line 163, in train_vae2(vae1, vae2, loader, config, device)
#     160 loss = vae2_loss(imgs, O1, residual, mu2, log2)
#     162 opt.zero_grad()
# --> 163 loss.backward()
#     164 opt.step()
#     165 tot += loss.item()
#
# File ~/miniconda3/envs/mlenv/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/miniconda3/envs/mlenv/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/miniconda3/envs/mlenv/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# Model outputs are collapsing to 0
